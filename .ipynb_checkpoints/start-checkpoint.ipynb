# %%
import numpy as np
import pandas as pd

# %%
source = pd.read_excel('data.xlsx',sheet_name='source')

# %%
df = pd.read_excel('data.xlsx',sheet_name='data')

# %%
source
# Out:
#                    محله  منطقه     شهر
# 0             حصاربوعلی       1  تهران
# 1    رستم آباد- فرمانیه       1  تهران
# 2                  اوین       1  تهران
# 3                  درکه       1  تهران
# 4              زعفرانیه       1  تهران
# ..                  ...     ...    ...
# 623          واریان شهر      10    کرج
# 624           کلاک بالا      11    کرج
# 625          کلاک پایین      11    کرج
# 626                حصار      11    کرج
# 627       شهرک جهان نما      11    کرج
#
# [628 rows x 3 columns]

# %%
df
# Out:
#        Number                                      Customer Name  \
# 0     1081095          ابراهیم آل ابراهیم - سایت تهران - 2237760
# 1     1117381                               جواد بیگلری سایت کرج
# 2     1104462                شرکت زنجیره ای غذایی امیران (برغان)
# 3     1104474               شرکت زنجیره ای غذایی امیران (عظیمیه)
# 4     1067853                 فروشگاه اتکا فاز 4 مهرشهر-سایت کرج
# ...       ...                                                ...
# 5997  1078592  وین مارکت کرشته1087 وین مارکت کرشته1087 - سایت...
# 5998  1079062       وین مارکت معلم (1062) - سایت تهران - 2252893
# 5999  1078676  وین مارکت ورامین 1089 وین مارکت ورامین 1089 - ...
# 6000  1079033   ویوان  باقر شهر فاتحی1030 - سایت تهران - 2253985
# 6001  1079032           ویوان شهر قدس1029 - سایت تهران - 2253977
#
#                                                 Details   Latitude  Longitude  \
# 0            خ محلاتی خ کیانی  خ میثم انتهای خیابان پ 7        ___        ___
# ...
